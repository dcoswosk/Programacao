# %%
import pandas as pd

vendas_df = pd.read_csv("[Opcional] Projeto Exercício de Revisão - Vendas_Chocolate.csv",sep=";")
display(vendas_df)
# Out:
#                 Vendedor         País                        Produto  \
# 0             João Rocha  Reino Unido   Chocolate com Menta e Flocos
# 1     Vanderlei Teixeira        Índia                            NaN
# 2         Gisele Barbosa        Índia  Cubos de Manteiga de Amendoim
# 3        Janaína Moreira    Austrália  Cubos de Manteiga de Amendoim
# 4             João Rocha  Reino Unido  Cubos de Manteiga de Amendoim
# ...                  ...          ...                            ...
# 3277      Karina Machado    Austrália    Especiais Apimentados Finos
# 3278          João Rocha          EUA               Chocolate Branco
# 3279        Célio Bonfim       Canadá   Xarope de Chocolate Orgânico
# 3280       Doroti Santos        Índia            Bombas de Chocolate
# 3281      Karina Machado        Índia             Mordidas 70% Cacau
#
#             Data       Valor  Caixas Enviadas Data de Hoje
# 0     04/01/2022   $5,320.00            180.0   03/02/2026
# 1     01/08/2022   $7,896.00             94.0          NaN
# 2     07/07/2022   $4,501.00             91.0          NaN
# 3     27/04/2022  $12,726.00            342.0          NaN
# 4     24/02/2022  $13,685.00            184.0          NaN
# ...          ...         ...              ...          ...
# 3277  17/05/2024   $5,303.58            354.0          NaN
# 3278  07/06/2024   $7,339.32            121.0          NaN
# 3279  26/07/2024     $616.09            238.0          NaN
# 3280  28/07/2024   $2,504.62            397.0          NaN
# 3281  23/05/2024   $5,915.87            355.0          NaN
#
# [3282 rows x 7 columns]

# %%
vendas_df = vendas_df.drop(columns=['Data de Hoje'])
vendas_df = vendas_df.dropna()
vendas_df.isnull().sum()
# Out:
# Vendedor           0
# País               0
# Produto            0
# Data               0
# Valor              0
# Caixas Enviadas    0
# dtype: int64

# %%
vendas_df["Data"] = pd.to_datetime(vendas_df['Data'],dayfirst=True)
vendas_df["Valor"] = vendas_df["Valor"].str.replace("$","").str.replace(",","")
vendas_df["Valor"] = vendas_df["Valor"].astype(float)
vendas_df = vendas_df.drop_duplicates()
vendas_df = vendas_df.reset_index(drop=True)
print(vendas_df.info())
display(vendas_df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3155 entries, 0 to 3154
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Vendedor         3155 non-null   str
#  1   País             3155 non-null   str
#  2   Produto          3155 non-null   str
#  3   Data             3155 non-null   datetime64[us]
#  4   Valor            3155 non-null   float64
#  5   Caixas Enviadas  3155 non-null   float64
# dtypes: datetime64[us](1), float64(2), str(3)
# memory usage: 289.1 KB
# None
#                 Vendedor         País                        Produto  \
# 0             João Rocha  Reino Unido   Chocolate com Menta e Flocos
# 1         Gisele Barbosa        Índia  Cubos de Manteiga de Amendoim
# 2        Janaína Moreira    Austrália  Cubos de Manteiga de Amendoim
# 3             João Rocha  Reino Unido  Cubos de Manteiga de Amendoim
# 4     Vanderlei Teixeira        Índia      Salgadinho Suave e Sedoso
# ...                  ...          ...                            ...
# 3150      Karina Machado    Austrália    Especiais Apimentados Finos
# 3151          João Rocha          EUA               Chocolate Branco
# 3152        Célio Bonfim       Canadá   Xarope de Chocolate Orgânico
# 3153       Doroti Santos        Índia            Bombas de Chocolate
# 3154      Karina Machado        Índia             Mordidas 70% Cacau
#
#            Data     Valor  Caixas Enviadas
# 0    2022-01-04   5320.00            180.0
# 1    2022-07-07   4501.00             91.0
# 2    2022-04-27  12726.00            342.0
# 3    2022-02-24  13685.00            184.0
# 4    2022-06-06   5376.00             38.0
# ...         ...       ...              ...
# 3150 2024-05-17   5303.58            354.0
# 3151 2024-06-07   7339.32            121.0
# 3152 2024-07-26    616.09            238.0
# 3153 2024-07-28   2504.62            397.0
# 3154 2024-05-23   5915.87            355.0
#
# [3155 rows x 6 columns]

# %%
display(vendas_df.describe())
# Out:
#                              Data         Valor  Caixas Enviadas
# count                        3155   3155.000000      3155.000000
# mean   2023-05-01 17:10:08.177496   6021.792041       164.105547
# min           2022-01-03 00:00:00      7.000000         1.000000
# 25%           2022-06-30 00:00:00   2510.805000        71.000000
# 50%           2023-05-10 00:00:00   5220.800000       137.000000
# 75%           2024-03-01 12:00:00   8548.920000       232.000000
# max           2024-08-31 00:00:00  26170.950000       778.000000
# std                           NaN   4393.267909       123.288244

# %%
vendas_df["Mes"] = vendas_df["Data"].dt.to_period("M")
vendas_df["Ano"] = vendas_df["Data"].dt.year
display(vendas_df)
# Out:
#                 Vendedor         País                        Produto  \
# 0             João Rocha  Reino Unido   Chocolate com Menta e Flocos
# 1         Gisele Barbosa        Índia  Cubos de Manteiga de Amendoim
# 2        Janaína Moreira    Austrália  Cubos de Manteiga de Amendoim
# 3             João Rocha  Reino Unido  Cubos de Manteiga de Amendoim
# 4     Vanderlei Teixeira        Índia      Salgadinho Suave e Sedoso
# ...                  ...          ...                            ...
# 3150      Karina Machado    Austrália    Especiais Apimentados Finos
# 3151          João Rocha          EUA               Chocolate Branco
# 3152        Célio Bonfim       Canadá   Xarope de Chocolate Orgânico
# 3153       Doroti Santos        Índia            Bombas de Chocolate
# 3154      Karina Machado        Índia             Mordidas 70% Cacau
#
#            Data     Valor  Caixas Enviadas      Mes   Ano
# 0    2022-01-04   5320.00            180.0  2022-01  2022
# 1    2022-07-07   4501.00             91.0  2022-07  2022
# 2    2022-04-27  12726.00            342.0  2022-04  2022
# 3    2022-02-24  13685.00            184.0  2022-02  2022
# 4    2022-06-06   5376.00             38.0  2022-06  2022
# ...         ...       ...              ...      ...   ...
# 3150 2024-05-17   5303.58            354.0  2024-05  2024
# 3151 2024-06-07   7339.32            121.0  2024-06  2024
# 3152 2024-07-26    616.09            238.0  2024-07  2024
# 3153 2024-07-28   2504.62            397.0  2024-07  2024
# 3154 2024-05-23   5915.87            355.0  2024-05  2024
#
# [3155 rows x 8 columns]

# %%
import plotly.express as px

# %%
vendas_mes = vendas_df[["Mes","Valor"]]
vendas_mes = vendas_mes.groupby("Mes", as_index=False).sum()
display(vendas_mes)
# Out:
#         Mes      Valor
# 0   2022-01  860363.00
# 1   2022-02  699377.00
# 2   2022-03  726418.00
# 3   2022-04  653198.00
# 4   2022-05  740103.00
# 5   2022-06  836465.00
# 6   2022-07  772177.00
# 7   2022-08  709065.00
# 8   2023-01  900155.00
# 9   2023-02  729416.95
# 10  2023-03  784291.08
# 11  2023-04  700551.88
# 12  2023-05  771805.90
# 13  2023-06  904244.36
# 14  2023-07  832202.18
# 15  2023-08  774201.54
# 16  2024-01  991213.56
# 17  2024-02  745158.10
# 18  2024-03  782700.99
# 19  2024-04  715688.85
# 20  2024-05  793438.83
# 21  2024-06  895428.01
# 22  2024-07  878875.18
# 23  2024-08  802215.48

# %%
grafico = px.bar(vendas_mes, x=vendas_mes["Mes"].astype(str), y="Valor")
grafico.show()

# %%
vendas_ano = vendas_df[["Ano","Valor","Caixas Enviadas"]]
vendas_ano = vendas_ano.groupby("Ano",as_index=False).sum()
vendas_ano["Ticket Medio"] = vendas_ano["Valor"] / vendas_ano["Caixas Enviadas"]
vendas_ano["% Crescimento Valor"] = vendas_ano["Valor"].pct_change()
display(vendas_ano.style.format({
    "Valor": "${:,.2f}",
    "Caixas Enviadas": "{:,.0f}",
    "Ticket Medio": "${:,.2f}",
    "% Crescimento Valor": "{:,.1%}",
}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_816a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_816a4_level0_col0" class="col_heading level0 col0" >Ano</th>
#       <th id="T_816a4_level0_col1" class="col_heading level0 col1" >Valor</th>
#       <th id="T_816a4_level0_col2" class="col_heading level0 col2" >Caixas Enviadas</th>
#       <th id="T_816a4_level0_col3" class="col_heading level0 col3" >Ticket Medio</th>
#       <th id="T_816a4_level0_col4" class="col_heading level0 col4" >% Crescimento Valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_816a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_816a4_row0_col0" class="data row0 col0" >2022</td>
#       <td id="T_816a4_row0_col1" class="data row0 col1" >$5,997,166.00</td>
#       <td id="T_816a4_row0_col2" class="data row0 col2" >171,422</td>
#       <td id="T_816a4_row0_col3" class="data row0 col3" >$34.98</td>
#       <td id="T_816a4_row0_col4" class="data row0 col4" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_816a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_816a4_row1_col0" class="data row1 col0" >2023</td>
#       <td id="T_816a4_row1_col1" class="data row1 col1" >$6,396,868.89</td>
#       <td id="T_816a4_row1_col2" class="data row1 col2" >173,970</td>
#       <td id="T_816a4_row1_col3" class="data row1 col3" >$36.77</td>
#       <td id="T_816a4_row1_col4" class="data row1 col4" >6.7%</td>
#     </tr>
#     <tr>
#       <th id="T_816a4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_816a4_row2_col0" class="data row2 col0" >2024</td>
#       <td id="T_816a4_row2_col1" class="data row2 col1" >$6,604,719.00</td>
#       <td id="T_816a4_row2_col2" class="data row2 col2" >172,361</td>
#       <td id="T_816a4_row2_col3" class="data row2 col3" >$38.32</td>
#       <td id="T_816a4_row2_col4" class="data row2 col4" >3.2%</td>
#     </tr>
#   </tbody>
# </table>

# %%
dt_produto_anual = vendas_df[["Ano","Produto","Valor"]]
dt_produto_anual = dt_produto_anual.groupby(["Ano","Produto"],as_index=False).sum()
display(dt_produto_anual)
# Out:
#      Ano                            Produto      Valor
# 0   2022                  99% Amargo e Puro  270144.00
# 1   2022    Amêndoas Cobertas com Chocolate  238847.00
# 2   2022                   Barras 85% Cacau  283297.00
# 3   2022      Barras Recheadas com Caramelo  231588.00
# 4   2022       Barras de Chocolate ao Leite  258867.00
# ..   ...                                ...        ...
# 61  2024  Gotas de Chocolate de Confeiteiro  281787.05
# 62  2024                 Mordidas 50% Cacau  355627.08
# 63  2024                 Mordidas 70% Cacau  237490.12
# 64  2024          Salgadinho Suave e Sedoso  370077.04
# 65  2024       Xarope de Chocolate Orgânico  327290.54
#
# [66 rows x 3 columns]

# %%
grafico = px.bar(dt_produto_anual, x="Ano", y="Valor", color="Produto")
grafico.show()
